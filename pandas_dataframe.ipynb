# %% [markdown]
# <a href="https://colab.research.google.com/github/barkamoljon/data_science_praktikum/blob/main/pandas_first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# # **AMALIYOT**
# ## DataFrame

# %% [markdown]
# ### **1-mashq**. `Pandas` kutubxonasini `pd`, `numpy` kutubxonasini `np` deb chaqirib oling

# %%
# Javobni shuyerga yozing
import pandas as pd
import numpy as np

# %% [markdown]
# ### **2-mashq.** Quyida ko'rsatilgan dataframeni yarating va `df` deb nomlang

# %%
#Javoblarni shu yerga yozing.
viloyatlar = [
    "Andijon viloyati",
    "Buxoro viloyati",
    "Fargona viloyati",
    "Jizzax viloyati",
    "Xorazm viloyati",
    "Namangan viloyati",
    "Navoiy viloyati",
    "Qashqadaryo viloyati",
    "Qoraqalpogʻiston Respublikasi",
    "Samarqand viloyati",
    "Sirdaryo viloyati",
    "Surxondaryo viloyati",
    "Toshkent viloyati",
]
markazlar = [
    "Andijon shahri",
    "Buxoro shahri",
    "Fargona shahri",
    "Jizzax shahri",
    "Urganch shahri",
    "Namangan shahri",
    "Navoiy shahri",
    "Qarshi shahri",
    "Nukus shahri",
    "Samarqand shahri",
    "Guliston shahri",
    "Termiz shahri",
    "Nurafshon shahri",
]
maydonlar = [
    4200,
    39400,
    6800,
    20500,
    6300,
    7900,
    110800,
    28400,
    160000,
    16400,
    5100,
    20800,
    15300,
]
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
data = {
    "Hudud":viloyatlar,
    "Markaz":markazlar,
    "Maydoni":maydonlar,
    "Aholisi":aholi
}
df = pd.DataFrame(data)
df
# Out:
#                             Hudud            Markaz  Maydoni  Aholisi
# 0                Andijon viloyati    Andijon shahri     4200  1899000
# 1                 Buxoro viloyati     Buxoro shahri    39400  1384700
# 2                Fargona viloyati    Fargona shahri     6800  2597000
# 3                 Jizzax viloyati     Jizzax shahri    20500   910500
# 4                 Xorazm viloyati    Urganch shahri     6300  1200000
# 5               Namangan viloyati   Namangan shahri     7900  1862000
# 6                 Navoiy viloyati     Navoiy shahri   110800   767500
# 7            Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri   160000  1200000
# 9              Samarqand viloyati  Samarqand shahri    16400  2322000
# 10              Sirdaryo viloyati   Guliston shahri     5100   648100
# 11           Surxondaryo viloyati     Termiz shahri    20800  1676000
# 12              Toshkent viloyati  Nurafshon shahri    15300  4450000

# %%
# @title **To'g'ri javob**
viloyatlar = [
    "Andijon viloyati",
    "Buxoro viloyati",
    "Fargona viloyati",
    "Jizzax viloyati",
    "Xorazm viloyati",
    "Namangan viloyati",
    "Navoiy viloyati",
    "Qashqadaryo viloyati",
    "Qoraqalpogʻiston Respublikasi",
    "Samarqand viloyati",
    "Sirdaryo viloyati",
    "Surxondaryo viloyati",
    "Toshkent viloyati",
]
markazlar = [
    "Andijon shahri",
    "Buxoro shahri",
    "Fargona shahri",
    "Jizzax shahri",
    "Urganch shahri",
    "Namangan shahri",
    "Navoiy shahri",
    "Qarshi shahri",
    "Nukus shahri",
    "Samarqand shahri",
    "Guliston shahri",
    "Termiz shahri",
    "Nurafshon shahri",
]
maydonlar = [
    4200,
    39400,
    6800,
    20500,
    6300,
    7900,
    110800,
    28400,
    160000,
    16400,
    5100,
    20800,
    15300,
]
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
data = {
    "Hudud":viloyatlar,
    "Markaz":markazlar,
    "Maydoni":maydonlar,
    "Aholisi":aholi
}
df = pd.DataFrame(data)
df
# Out:
#                             Hudud            Markaz  Maydoni  Aholisi
# 0                Andijon viloyati    Andijon shahri     4200  1899000
# 1                 Buxoro viloyati     Buxoro shahri    39400  1384700
# 2                Fargona viloyati    Fargona shahri     6800  2597000
# 3                 Jizzax viloyati     Jizzax shahri    20500   910500
# 4                 Xorazm viloyati    Urganch shahri     6300  1200000
# 5               Namangan viloyati   Namangan shahri     7900  1862000
# 6                 Navoiy viloyati     Navoiy shahri   110800   767500
# 7            Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri   160000  1200000
# 9              Samarqand viloyati  Samarqand shahri    16400  2322000
# 10              Sirdaryo viloyati   Guliston shahri     5100   648100
# 11           Surxondaryo viloyati     Termiz shahri    20800  1676000
# 12              Toshkent viloyati  Nurafshon shahri    15300  4450000

# %% [markdown]
# ### **2-mashq.** Yuqoridagi df ning yuqorisidan 5 ta qator chiqaring

# %%
# Javobni shuyerga yozing
df.head()
# Out:
#               Hudud          Markaz  Maydoni  Aholisi
# 0  Andijon viloyati  Andijon shahri     4200  1899000
# 1   Buxoro viloyati   Buxoro shahri    39400  1384700
# 2  Fargona viloyati  Fargona shahri     6800  2597000
# 3   Jizzax viloyati   Jizzax shahri    20500   910500
# 4   Xorazm viloyati  Urganch shahri     6300  1200000

# %%
#@title **To'g'ri javob**
df.head()
# Out:
#               Hudud          Markaz  Maydoni  Aholisi
# 0  Andijon viloyati  Andijon shahri     4200  1899000
# 1   Buxoro viloyati   Buxoro shahri    39400  1384700
# 2  Fargona viloyati  Fargona shahri     6800  2597000
# 3   Jizzax viloyati   Jizzax shahri    20500   910500
# 4   Xorazm viloyati  Urganch shahri     6300  1200000

# %% [markdown]
# ### **3-mashq.** Yuqoridagi df dan tasodifiy 3 ta qator chiqaring

# %%
# Javobni shuyerga yozing
df.sample(3)
# Out:
#                 Hudud            Markaz  Maydoni  Aholisi
# 0    Andijon viloyati    Andijon shahri     4200  1899000
# 3     Jizzax viloyati     Jizzax shahri    20500   910500
# 9  Samarqand viloyati  Samarqand shahri    16400  2322000

# %%
#@title **To'g'ri javob**
df.sample(3)
# Out:
#                             Hudud            Markaz  Maydoni  Aholisi
# 12              Toshkent viloyati  Nurafshon shahri    15300  4450000
# 2                Fargona viloyati    Fargona shahri     6800  2597000
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri   160000  1200000

# %% [markdown]
# ### **4-mashq.** Yuqoridagi df ning 'Hudud' va 'Aholisi' ustinlarini alohida df ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
df[["Hudud",'Aholisi']]
# Out:
#                             Hudud  Aholisi
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2                Fargona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %%
#@title **To'g'ri javob**
df[['Hudud','Aholisi']]
# Out:
#                             Hudud  Aholisi
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2                Fargona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %% [markdown]
# ### **5-mashq.** Yuqoridagi df ning `Markaz` ustunini Series obyekti ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
df['Markaz']
# Out:
# 0       Andijon shahri
# 1        Buxoro shahri
# 2       Fargona shahri
# 3        Jizzax shahri
# 4       Urganch shahri
# 5      Namangan shahri
# 6        Navoiy shahri
# 7        Qarshi shahri
# 8         Nukus shahri
# 9     Samarqand shahri
# 10     Guliston shahri
# 11       Termiz shahri
# 12    Nurafshon shahri
# Name: Markaz, dtype: object

# %%
#@title **To'g'ri javob**
df.Markaz
# Out:
# 0       Andijon shahri
# 1        Buxoro shahri
# 2       Fargona shahri
# 3        Jizzax shahri
# 4       Urganch shahri
# 5      Namangan shahri
# 6        Navoiy shahri
# 7        Qarshi shahri
# 8         Nukus shahri
# 9     Samarqand shahri
# 10     Guliston shahri
# 11       Termiz shahri
# 12    Nurafshon shahri
# Name: Markaz, dtype: object

# %% [markdown]
# ### **6-mashq.** Yuqoridagi df dan aholi soni 2 milliondan oshiq bo'lgan hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df[['Aholisi']][df["Aholisi"]>2_000_000]
# Out:
#     Aholisi
# 2   2597000
# 7   2029000
# 9   2322000
# 12  4450000

# %%
#@title **To'g'ri javob**
df[df.Aholisi>2_000_000]
# Out:
#                    Hudud            Markaz  Maydoni  Aholisi
# 2       Fargona viloyati    Fargona shahri     6800  2597000
# 7   Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 9     Samarqand viloyati  Samarqand shahri    16400  2322000
# 12     Toshkent viloyati  Nurafshon shahri    15300  4450000

# %% [markdown]
# ### **7-mashq.** Yuqoridagi df dan maydoni 10000kv.km dan kichik bo'lgan hududlarni chiqaring

# %%
# Javobni shuyerga yozing
#df[['Maydoni']][df['Maydoni']<10_000]
df[df.Maydoni<10_000]
# Out:
#                 Hudud           Markaz  Maydoni  Aholisi
# 0    Andijon viloyati   Andijon shahri     4200  1899000
# 2    Fargona viloyati   Fargona shahri     6800  2597000
# 4     Xorazm viloyati   Urganch shahri     6300  1200000
# 5   Namangan viloyati  Namangan shahri     7900  1862000
# 10  Sirdaryo viloyati  Guliston shahri     5100   648100

# %%
#@title **To'g'ri javob**
df[df.Maydoni<10000]
# Out:
#                 Hudud           Markaz  Maydoni  Aholisi
# 0    Andijon viloyati   Andijon shahri     4200  1899000
# 2    Fargona viloyati   Fargona shahri     6800  2597000
# 4     Xorazm viloyati   Urganch shahri     6300  1200000
# 5   Namangan viloyati  Namangan shahri     7900  1862000
# 10  Sirdaryo viloyati  Guliston shahri     5100   648100

# %% [markdown]
# ### **8-mashq.** Yuqoridagi df ning birinchi ustunini df ning indeksi sifatida ishlating
# Ishora:
# 1. Yoki df ni qayta yarating
# 2. Yoki `set_index()` metodidan foydalaning

# %%
# Javobni shuyerga yozing
df.set_index(df.columns[0],inplace=True)
df.head()
# Out:
#                           Markaz  Maydoni  Aholisi
# Hudud
# Andijon viloyati  Andijon shahri     4200  1899000
# Buxoro viloyati    Buxoro shahri    39400  1384700
# Fargona viloyati  Fargona shahri     6800  2597000
# Jizzax viloyati    Jizzax shahri    20500   910500
# Xorazm viloyati   Urganch shahri     6300  1200000

# %%
#@title **To'g'ri javob**
df.set_index(df.columns[0], inplace=True)
df.head()
# Out:
#                 Maydoni  Aholisi
# Markaz
# Andijon shahri     4200  1899000
# Buxoro shahri     39400  1384700
# Fargona shahri     6800  2597000
# Jizzax shahri     20500   910500
# Urganch shahri     6300  1200000

# %% [markdown]
# ### **9-mashq.** Yuqoridagi df dan, Aholisi 2 milliondan oshiq hududlar orasida Samarqand viloyati bor yoki yo'qligini tekshiring

# %%
# Javobni shuyerga yozing
'Samarqand viloyati' in df[df>2_000_000]
# Out:
# False

# %%
#@title **To'g'ri javob**
"Samarqand viloyati" in df[df.Aholisi>2_000_000].index
# Out:
# False

# %% [markdown]
# ### **10-mashq.**  Yuqoridagi df dan faqatgina Andijon, Farg'ona va Namangan viloyatlarini ajratib ko'rsating

# %%
# Javobni shuyerga yozing
#df.loc[['Andijon viloyati','Farg`ona viloyati','Namangan viloyati']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-2dc7f1d895d1> in <module>()
#       1 # Javobni shuyerga yozing
# ----> 2 df.loc[['Andijon viloyati','Farg`ona viloyati','Namangan viloyati']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Andijon viloyati', 'Farg`ona viloyati', 'Namangan viloyati'], dtype='object', name='Markaz')] are in the [index]"

# %%
#@title **To'g'ri javob**
#df.loc[["Andijon viloyati","Fargona viloyati","Namangan viloyati"]]

# %% [markdown]
# ### **11-mashq.**  Yuqoridagi df dan Samarqanda va Toshkent viloyatlarining aholisi va maydonini alohida df ko'rinishida chiqaring

# %%
viloyatlar = [
    "Andijon viloyati",
    "Buxoro viloyati",
    "Fargona viloyati",
    "Jizzax viloyati",
    "Xorazm viloyati",
    "Namangan viloyati",
    "Navoiy viloyati",
    "Qashqadaryo viloyati",
    "Qoraqalpogʻiston Respublikasi",
    "Samarqand viloyati",
    "Sirdaryo viloyati",
    "Surxondaryo viloyati",
    "Toshkent viloyati",
]
markazlar = [
    "Andijon shahri",
    "Buxoro shahri",
    "Fargona shahri",
    "Jizzax shahri",
    "Urganch shahri",
    "Namangan shahri",
    "Navoiy shahri",
    "Qarshi shahri",
    "Nukus shahri",
    "Samarqand shahri",
    "Guliston shahri",
    "Termiz shahri",
    "Nurafshon shahri",
]
maydonlar = [
    4200,
    39400,
    6800,
    20500,
    6300,
    7900,
    110800,
    28400,
    160000,
    16400,
    5100,
    20800,
    15300,
]
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
data = {
    "Hudud":viloyatlar,
    "Markaz":markazlar,
    "Maydoni":maydonlar,
    "Aholisi":aholi
}
df = pd.DataFrame(data)
df

# %%
df.loc[['Toshkent viloyati','Samarqand viloyati'],['Maydoni','Aholisi']]

# %%
#@title **To'g'ri javob**
df.loc[['Toshkent viloyati','Samarqand viloyati'],['Maydoni','Aholisi']]

# %% [markdown]
# ### **12-mashq.**  Yuqoridagi df dan yangi df_new DataFrame yarating. Yangi dataframega faqatgina aholisi 1.5mln dan kam bo'lgan hududlarni ko'chiring.

# %%
# Javobni shuyerga yozing
df_new=df[df.Aholisi<1_500_000]
df_new

# %%
#@title **To'g'ri javob**
df_new = df[df.Aholisi<1_500_000]
df_new

# %% [markdown]
# ### **13-mashq.**  Yangi df qatorlari orasida Navoiy, Namangan va Xorazm viloyatlari borligini tekshiring

# %%
# Javobni shuyerga yozing
pd.Index(['Navoiy viloyati','Namangan viloyati','Xorazm viloyati']).isin(df_new.index)

# %%
#@title **To'g'ri javob**
pd.Index(['Navoiy viloyati','Namangan viloyati','Xorazm viloyati']).isin(df_new.index)

# %% [markdown]
# ### **14-mashq.**  Aholisi 1milliondan ko'p, lekin maydoni 10000kv.km dan kam hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df[(df.Aholisi>1_000_000)&(df.Maydoni<10_000)]

# %%
#@title **To'g'ri javob**
df[(df.Aholisi>1_000_000) & (df.Maydoni<10000)]

# %% [markdown]
# ### **15-mashq.**  Aholisi 1milliondan kam, lekin maydoni 10000kv.km dan ko'p hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df[(df.Aholisi<1_000_000)&(df.Maydoni>10_000)]

# %%
#@title **To'g'ri javob**
df[(df.Aholisi<1_000_000) & (df.Maydoni>10000)]

# %% [markdown]
# ### **16-mashq.**  Yuqoridagi df dan `Markaz` ustunini tashlab yuboring

# %%
# Javobni shuyerga yozing
df.drop(['Markaz'],axis=1)

# %%
#@title **To'g'ri javob**
df.drop(['Markaz'], axis=1)

# %% [markdown]
# ### **17-mashq.**  Yuqoridagi df dan Sirdaryo viloyati aholisini chiqaring

# %%
# Javobni shuyerga yozing
df.at['Sirdaryo viloyati','Aholisi']

# %%
#@title **To'g'ri javob**
df.at['Sirdaryo viloyati','Aholisi']

# %% [markdown]
# ### **18-mashq.**  Yuqoridagi df dan Buxoro viloyati maydonini chiqaring

# %%
# Javobni shuyerga yozing
df.at['Buxoro viloyati','Maydoni']

# %%
#@title **To'g'ri javob**
df.at['Buxoro viloyati','Maydoni']

# %% [markdown]
# ### **19-mashq.**  Yuqoridagi df dan Toshkent viloyati maydoni O'zbekiston Respublikasining necha fozini tashkil qilishini toping

# %%
# Javobni shuyerga yozing
tosh_maydon=df.at['Toshkent viloyati','Maydoni']
uzb_maydon=df.Maydoni.sum()
print(f'Toshkent viloyati maydoni:{tosh_maydon}kv.km')
print(f'O`zbekiston Respublikasi maydoni:{uzb_maydon}kv.km')
print(f'Toshkent viloyati hududi O`zbekiston umumiy hududini {(tosh_maydon/uzb_maydon)*100}% ni tashkil qiladi.')

# %%
#@title **To'g'ri javob**
tosh_area = df.at['Toshkent viloyati','Maydoni']
uzb_area = sum(df.Maydoni) # yoki
# uzb_area = df.Maydoni.sum()
print(f"Toshkent viloyati maydoni: {tosh_area} kv.km")
print(f"O'zbekiston Respublikasi maydoni: {uzb_area} kv.km")
print(f"Toshkent viloyati maydoni O'zbekiston respublikasining {round(tosh_area/uzb_area*100)}% ni tashkil qiladi")

# %% [markdown]
# ### **20-mashq.**  Yuqoridagi df dan Toshkent viloyati aholisi O'zbekiston Respublikasining necha fozini tashkil qilishini toping

# %%
# Javobni shuyerga yozing
tosh_aholi=df.at['Toshkent viloyati','Aholisi']
uzb_aholi=df.Aholisi.sum()
print(f'Toshkent viloyati aholisi:{tosh_aholi}')
print(f'O`zbekiston aholisi:{uzb_aholi}')
print(f'Toshkent viloyati aholisi O`zbekiston aholisining:{round(tosh_aholi/uzb_aholi*100)}% ga teng.')

# %%
#@title **To'g'ri javob**
tosh_area = df.at['Toshkent viloyati','Aholisi']
uzb_area = sum(df.Aholisi) # yoki
# uzb_area = df.Maydoni.sum()
print(f"Toshkent viloyati aholisi: {tosh_area} kishi")
print(f"O'zbekiston Respublikasi aholisi: {uzb_area} kishi")
print(f"Toshkent viloyati aholisi O'zbekiston respublikasining {round(tosh_area/uzb_area*100)}% ni tashkil qiladi")
