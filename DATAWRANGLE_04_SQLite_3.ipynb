# %% [markdown]
# <a href="https://colab.research.google.com/github/barkamoljon/data_science_praktikum/blob/main/DATAWRANGLE_04_SQLite_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jovian Commit Essentials
# Please retain and execute this cell without modifying the contents for `jovian.commit` to work
# !pip install jovian --upgrade -q
import jovian
jovian.set_project('03-datawrangle-04-sqlite-3')
jovian.set_colab_id('1jTYvnPQMc9CVR5ILH-OlWiP32I7_fVMk')
# Out:
#      |████████████████████████████████| 68 kB 936 kB/s
# ...

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 3-MODUL. MA’LUMOTLARGA ISHLOV BERISH
#
# ### 3.1 Fayllar bilan ishlash
#
# #### Ma'lumotlar ombori. 3-qism
#
# ## Qo'shimcha foydali buyruqlar

# %%
import pandas as pd
import sqlite3 as sql

# %% [markdown]
# Darsimiz uchun MO yuklab olamiz

# %%
from urllib.request import urlretrieve
url = "https://github.com/anvarnarz/praktikum_datasets/raw/main/electricity.db"
urlretrieve(url,'electricity.db') # faylni yuklab olish
# Out:
# ('electricity.db', <http.client.HTTPMessage at 0x7fae02309690>)

# %% [markdown]
# Omborga ulanamiz

# %%
db =sql.connect("electricity.db")
cursor = db.cursor()

# %% [markdown]
# Ombor tarkibidagi jadvallarni ko'ramiz

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('elect',)]

# %% [markdown]
# Jadval ustunlarini ko'ramiz

# %%
cursor.execute("PRAGMA table_info(elect);")
cursor.fetchall()
# Out:
# [(0, 'index', 'INTEGER', 0, None, 0),
#  (1, 'country', 'TEXT', 0, None, 0),
#  (2, 'code', 'TEXT', 0, None, 0),
#  (3, 'year', 'INTEGER', 0, None, 0),
#  (4, 'coal', 'REAL', 0, None, 0),
#  (5, 'gas', 'REAL', 0, None, 0),
#  (6, 'hydro', 'REAL', 0, None, 0),
#  (7, 'renewable_other', 'REAL', 0, None, 0),
#  (8, 'solar', 'REAL', 0, None, 0),
#  (9, 'oil', 'REAL', 0, None, 0),
#  (10, 'wind', 'REAL', 0, None, 0),
#  (11, 'nuclear', 'REAL', 0, None, 0)]

# %% [markdown]
# Ushbu jadvalda bizga avvalgi darslardan tanish bo'lgan dunyo davlatlarining elektr manbaalari haqidagi ma'lumotlar jamlangan.
#
# Keling jadval yuqorisidan 10 qator olib ko'ramiz.

# %%
pd.read_sql("SELECT * FROM elect LIMIT 10", db, index_col="index")
# Out:
#            country code  year  coal    gas  hydro  renewable_other  solar  \
# index
# 0      Afghanistan  AFG  2000   0.0  0.155  0.312              0.0    0.0
# 1      Afghanistan  AFG  2001   0.0  0.094  0.498              0.0    0.0
# 2      Afghanistan  AFG  2002   0.0  0.132  0.555              0.0    0.0
# 3      Afghanistan  AFG  2003   0.0  0.309  0.630              0.0    0.0
# 4      Afghanistan  AFG  2004   0.0  0.329  0.565              0.0    0.0
# 5      Afghanistan  AFG  2005   0.0  0.344  0.590              0.0    0.0
# 6      Afghanistan  AFG  2006   0.0  0.200  0.637              0.0    0.0
# 7      Afghanistan  AFG  2007   0.0  0.198  0.748              0.0    0.0
# 8      Afghanistan  AFG  2008   0.0  0.186  0.542              0.0    0.0
# 9      Afghanistan  AFG  2009   0.0  0.162  0.776              0.0    0.0
#
#        oil     wind  nuclear
# index
# 0      0.0  0.00000      0.0
# 1      0.0  0.00000      0.0
# 2      0.0  0.00000      0.0
# ...

# %% [markdown]
# ## Foydali buyruqlar
#
# ### `DISTINCT`
#
# `DISTINCT` buyru'gi bilan avvalgi darsda tanishgan edik.

# %%
query = "SELECT DISTINCT country FROM elect"
countries = pd.read_sql(query, db)
countries.head(10)
# Out:
#                country
# 0          Afghanistan
# 1               Africa
# 2              Albania
# 3              Algeria
# 4       American Samoa
# 5               Angola
# 6           Antarctica
# 7  Antigua and Barbuda
# 8            Argentina
# 9              Armenia

# %% [markdown]
# Davlatlar orasida `Uzbekistan` borligini tekshirib ko'ramiz

# %%
'Uzbekistan' in countries['country'].values
# Out:
# True

# %% [markdown]
# O'zbekistonga oid ma'lumotlarni ajratib olamiz

# %%
query = "SELECT * FROM elect WHERE country='Uzbekistan'"
dfuz = pd.read_sql(query,db)
dfuz.head()
# Out:
#    index     country code  year       coal        gas  hydro  renewable_other  \
# 0   5964  Uzbekistan  UZB  2000  11.602405  25.523451  5.817              0.0
# 1   5965  Uzbekistan  UZB  2001  11.766320  25.884038  5.899              0.0
# 2   5966  Uzbekistan  UZB  2002  12.214374  26.869686  6.124              0.0
# 3   5967  Uzbekistan  UZB  2003  11.833513  26.031852  7.544              0.0
# 4   5968  Uzbekistan  UZB  2004  11.595776  25.508869  8.920              0.0
#
#    solar       oil  wind  nuclear
# 0    0.0  1.380143   0.0      0.0
# 1    0.0  1.399642   0.0      0.0
# 2    0.0  1.452939   0.0      0.0
# 3    0.0  1.407634   0.0      0.0
# 4    0.0  1.379355   0.0      0.0

# %%
query = "SELECT * FROM elect WHERE country='Uzbekistan' AND year>2010"
dfuz = pd.read_sql(query,db)
dfuz
# Out:
#    index     country code  year       coal        gas     hydro  \
# 0   5975  Uzbekistan  UZB  2011  10.534094  32.487781  5.646000
# 1   5976  Uzbekistan  UZB  2012  10.365016  31.966333  6.586000
# 2   5977  Uzbekistan  UZB  2013  10.939346  33.737603  5.647000
# 3   5978  Uzbekistan  UZB  2014  11.112674  34.272157  6.014000
# 4   5979  Uzbekistan  UZB  2015  10.519789  35.780629  6.998000
# 5   5980  Uzbekistan  UZB  2016  10.783891  36.678911  7.254000
# 6   5981  Uzbekistan  UZB  2017  10.998707  37.409561  8.343000
# 7   5982  Uzbekistan  UZB  2018  11.853192  40.315893  5.838030
# 8   5983  Uzbekistan  UZB  2019  12.297660  41.827647  5.451373
#
#    renewable_other     solar       oil  wind  nuclear
# 0              0.0  0.000000  1.253064   0.0      0.0
# 1              0.0  0.000000  1.232952   0.0      0.0
# 2              0.0  0.001996  1.301270   0.0      0.0
# 3              0.0  0.002046  1.321888   0.0      0.0
# ...

# %% [markdown]
# ### `BETWEEN` yordamida filtrlash
# **Between** so'zi ingliz tildan __oraliqda__ deb tarjima qilinadi. Bu operator yordamida ma'lum oraliqdagi qiymatlarni ajratib olishimiz mumkin.
#
# Misol uchu, kelin O'zbekiston uchun 2010 va 2021 oraliqdagi ma'lumotlarni chaqirib olamiz.

# %%
query = "SELECT * FROM elect WHERE country='Uzbekistan' AND year BETWEEN 2010 AND 2021"
pd.read_sql(query, db)
# Out:
#    index     country code  year       coal        gas     hydro  \
# 0   5974  Uzbekistan  UZB  2010   9.792027  30.199200  8.110000
# 1   5975  Uzbekistan  UZB  2011  10.534094  32.487781  5.646000
# 2   5976  Uzbekistan  UZB  2012  10.365016  31.966333  6.586000
# 3   5977  Uzbekistan  UZB  2013  10.939346  33.737603  5.647000
# 4   5978  Uzbekistan  UZB  2014  11.112674  34.272157  6.014000
# 5   5979  Uzbekistan  UZB  2015  10.519789  35.780629  6.998000
# 6   5980  Uzbekistan  UZB  2016  10.783891  36.678911  7.254000
# 7   5981  Uzbekistan  UZB  2017  10.998707  37.409561  8.343000
# 8   5982  Uzbekistan  UZB  2018  11.853192  40.315893  5.838030
# 9   5983  Uzbekistan  UZB  2019  12.297660  41.827647  5.451373
#
#    renewable_other     solar       oil  wind  nuclear
# 0              0.0  0.000000  1.164793   0.0      0.0
# 1              0.0  0.000000  1.253064   0.0      0.0
# 2              0.0  0.000000  1.232952   0.0      0.0
# ...

# %% [markdown]
# ### `IN`
# `IN` yordamida filterlashda aniq qiymatlarni ko'rsatishimiz mumkin. Quyidagi misolda aynan 1990,1995,2000,2005,2010-yillardagi qiymatlarni ajratib olamiz.

# %%
query = "SELECT * FROM elect WHERE country='Uzbekistan' AND year IN (1990,1995,2000,2005,2010)"
pd.read_sql(query, db)
# Out:
#    index     country code  year       coal        gas  hydro  renewable_other  \
# 0   5964  Uzbekistan  UZB  2000  11.602405  25.523451  5.817              0.0
# 1   5969  Uzbekistan  UZB  2005  11.490919  25.278199  8.838              0.0
# 2   5974  Uzbekistan  UZB  2010   9.792027  30.199200  8.110              0.0
# 3   5989  Uzbekistan  UZB  1990        NaN        NaN  6.648              0.0
# 4   5994  Uzbekistan  UZB  1995        NaN        NaN  6.188              0.0
#
#    solar       oil  wind  nuclear
# 0    0.0  1.380143   0.0      0.0
# 1    0.0  1.366882   0.0      0.0
# 2    0.0  1.164793   0.0      0.0
# 3    0.0       NaN   0.0      0.0
# 4    0.0       NaN   0.0      0.0

# %% [markdown]
# ### `LIKE`
# `LIKE` yordamida ustun orasidan berilgan matnga o'xshash qiymatlarni topish mumkin. Qidiruv matnida `%` yoki `_` belgilari ishlatilishi mumkin.
# - `%` - bir nechta belgini anglatadi, masalan `'%stan'` matni `stan` so'zi bilan tugaydigan barcha qiymatlarni topadi.
# - `_` - bitta belgini anglatadi, misol uchun `_tol` matni 4 harfdan iborat `tol` bilan tugaydian so'zlarni topadi (`stol`)

# %% [markdown]
# Quyida `stan` bilan tugaydigan barcha davlatlar uchun 2019,2020,2021-yillardagi ma'lumotlarni olamiz

# %%
query = "SELECT * FROM elect WHERE country LIKE '%stan' AND year IN (2019, 2020, 2021)"
pd.read_sql(query, db)
# Out:
#    index       country code  year       coal        gas      hydro  \
# 0     19   Afghanistan  AFG  2019   0.000000   0.152000   0.840000
# 1   2847    Kazakhstan  KAZ  2019  71.206910  18.960820   9.842580
# 2   2848    Kazakhstan  KAZ  2020  72.193448  19.223513   9.403480
# 3   2963    Kyrgyzstan  KGZ  2019   1.056225   0.000000  13.705560
# 4   4303      Pakistan  PAK  2019  24.827532  24.776677  43.146492
# 5   4304      Pakistan  PAK  2020  29.319484  17.517486  47.296196
# 6   5495    Tajikistan  TJK  2019   0.000000   0.000000  18.977310
# 7   5496    Tajikistan  TJK  2020   0.000000   0.000000  18.489310
# 8   5704  Turkmenistan  TKM  2019   0.000000   7.230340   0.000300
# 9   5983    Uzbekistan  UZB  2019  12.297660  41.827647   5.451373
#
#    renewable_other     solar        oil      wind   nuclear
# 0         0.000000  0.040000   0.000000  0.000000  0.000000
# 1         0.001000  0.236000   0.755650  0.549000  0.000000
# ...

# %% [markdown]
# Quyida `A` bilan boshlanadigan barcha davlatlar uchun 2020-yil ma'lumotlarni olamiz. Ahamiyat bering bu safar davlat nomi emas kodi (`code`) dan foydalanamiz va qidiruv matnida `A` dan keyin ikki pastki chiziq (ikkita harf) yozayapmiz `A__`

# %%
query = "SELECT * FROM elect WHERE code LIKE 'A__' AND year=2020"
pd.read_sql(query, db)
# Out:
#    index     country code  year        coal        gas      hydro  \
# 0    225   Argentina  ARG  2020    1.445719  86.689660  20.853642
# 1    336   Australia  AUS  2020  135.099330  48.132519  16.112890
# 2    357     Austria  AUT  2020    0.716660  10.440827  42.883119
# 3    393  Azerbaijan  AZE  2020    0.000000  12.514432   1.549350
#
#    renewable_other      solar        oil       wind    nuclear
# 0         1.893496   1.344267   3.492022   9.419758  10.010408
# 1         3.443160  18.638820   5.612541  24.308719   0.000000
# 2         4.068629   1.264996   3.249908   6.868170   0.000000
# 3         0.155333   0.044000  11.379848   0.135000   0.000000

# %%
db.close()
